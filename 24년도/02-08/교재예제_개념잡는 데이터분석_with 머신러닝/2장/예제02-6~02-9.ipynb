# %% [markdown]
# # 2장 파이썬 핵심 문법

# %% [markdown]
# ## 2.6 리스트 내포

# %%
num = [-20,-10,0,10,20]
[x for x in num]
# Out:
# [-20, -10, 0, 10, 20]

# %%
num = [-20,-10,0,10,20]
[x+5 for x in num]
# Out:
# [-15, -5, 5, 15, 25]

# %%
num = [-20,-10,0,10,20]
[x/5 for x in num]
# Out:
# [-4.0, -2.0, 0.0, 2.0, 4.0]

# %%
num = [-20,-10,0,10,20]
[x**2 for x in num]
# Out:
# [400, 100, 0, 100, 400]

# %%
num = [-20,-10,0,10,20]
[1/x for x in num]
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-f8c224ade2e9> in <module>()
#       1 num = [-20,-10,0,10,20]
# ----> 2 [1/x for x in num]
#
# <ipython-input-6-f8c224ade2e9> in <listcomp>(.0)
#       1 num = [-20,-10,0,10,20]
# ----> 2 [1/x for x in num]
#
# ZeroDivisionError: division by zero

# %%
num = [-20,-10,0,10,20]
[1/x for x in num if x>0]
# Out:
# [0.1, 0.05]

# %%
num = [-20,-10,0,10,20]
[1/x for x in num if x!=0]
# Out:
# [-0.05, -0.1, 0.1, 0.05]

# %% [markdown]
# ## 2.7 선택문

# %% [markdown]
# ## 2.8 반복문과 기타 제어문

# %%
while True:
    pass

# %%
for x in range(10):
    pass

# %% [markdown]
# ## 2.9 함수

# %%
for x, name in enumerate(['수박', '참외', '자두']):
    print(x, name)
# Out:
# 0 수박
# 1 참외
# 2 자두

# %%
num = [1, 2, 3]
char = ['A', 'B', 'C']
for item in zip(num, char):
    print(item)
# Out:
# (1, 'A')
# (2, 'B')
# (3, 'C')

# %%
num = [1, 2, 3]
char = ['A', 'B', 'C']
dict(zip(num, char))
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %%
import random

for i in range(10):
    x = random.random()
    print(x)
# Out:
# 0.3224264731476373
# 0.2866795244950314
# 0.9412983845881466
# 0.8929275941085302
# 0.13440387844063206
# 0.6691989834794244
# 0.4030536468196264
# 0.4707457206515113
# 0.5619071300522646
# 0.058776174730835073

# %%
import random
random.randint(5, 10)
# Out:
# 6

# %%
random.randint(5, 10)
# Out:
# 10

# %%
import random
num = [1, 2, 3]
random.choice(num)
# Out:
# 1

# %%
random.choice(num)
# Out:
# 3

# %%
def max1(num1,num2):
    if num1>num2:
        return num1
    else:
        return num2
x = int(input('정수1: '))
y = int(input('정수2: '))
print('큰수:',max1(x,y))
# Out:
# 정수1: 35
# 정수2: 25
# 큰수: 35

# %%
def plus_five(x):
  return x + 5

plus_five(20)
# Out:
# 25

# %%
lambda x: x + 5
# Out:
# <function __main__.<lambda>>

# %%
plus_five = lambda x: x + 5
plus_five(20)
# Out:
# 25

# %%
def plus_five(x):
  return x + 5

list(map(plus_five, [15, 25, 35]))
# Out:
# [20, 30, 40]

# %%
list(map(lambda x: x + 5, [15, 25, 35]))
# Out:
# [20, 30, 40]
