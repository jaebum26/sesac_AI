# %% [markdown]
# # 2장 파이썬 핵심 문법

# %% [markdown]
# ## 2.1 코랩 환경

# %%
print('안녕 파이썬!!')

# %%
x = 10
y = 20
print(x+y)
# Out:
# 30

# %% [markdown]
# ## 2.2 변수

# %%
a=100
print(a)
# Out:
# 100

# %%
a=100
a=200
print(a)
# Out:
# 200

# %%
name='이순신'
addr='서울시'
print(name, addr)
# Out:
# 이순신 서울시

# %%
age=20
age=age+5
print('5년 후 나이', age)
# Out:
# 5년 후 나이 25

# %% [markdown]
# ## 2.3 연산자

# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
print(x-y)
# Out:
# -10

# %%
print(x*y)
# Out:
# 200

# %%
x=10
y=20
print(x/y)
# Out:
# 0.5

# %%
print(x%y)
# Out:
# 10

# %%
print(x**2)
# Out:
# 100

# %%
print(x//y)
# Out:
# 0

# %%
start='파이썬'
end=' 짱!'
start+end
# Out:
# '파이썬 짱!'

# %%
word='파이썬 '
word*5
# Out:
# '파이썬 파이썬 파이썬 파이썬 파이썬 '

# %% [markdown]
# ## 2.4 표준 입·출력

# %%
name = input('이름 입력: ')
print(name)
# Out:
# 이름 입력: 이순신
# 이순신

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print(x+y)
# Out:
# 숫자1 입력: 20
# 숫자2 입력: 30
# 50

# %%
z = float(input('숫자 입력: '))
print(z)
# Out:
# 숫자 입력: 7.5
# 7.5

# %%
print('파이썬')
print('짱')
# Out:
# 파이썬
# 짱

# %%
print('파이썬', end=' ')
print('짱')
# Out:
# 파이썬 짱

# %%
name = input('이름 입력: ')
print('입력한 이름은', name)
# Out:
# 이름 입력: 이순신
# 입력한 이름은 이순신

# %%
name = input('이름 입력: ')
print('입력한 이름은 %s' % name)
# Out:
# 이름 입력: 이순신
# 입력한 이름은 이순신

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('%d + %d = %d' % (x, y, x+y))
# Out:
# 숫자1 입력: 20
# 숫자2 입력: 30
# 20 + 30 = 50

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('%d / %d = %f' % (x, y, x/y))
# Out:
# 숫자1 입력: 5
# 숫자2 입력: 2
# 5 / 2 = 2.500000

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('{0} * {1} = {2}'.format(x, y, x*y))
# Out:
# 숫자1 입력: 7
# 숫자2 입력: 3
# 7 * 3 = 21

# %%
print('{1} {1} 작은 {0}'.format('별','반짝'))
# Out:
# 반짝 반짝 작은 별

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print(f'{x} - {y} = {x-y}')
# Out:
# 숫자1 입력: 30
# 숫자2 입력: 20
# 30 - 20 = 10
