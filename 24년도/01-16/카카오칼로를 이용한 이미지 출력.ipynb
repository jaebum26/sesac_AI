# %%
from PyKakao import Karlo

key = '7640665a18c8b4e2ea4c5cbeb89d24d6'
k=Karlo(service_key=key)

text = ''' Cute magical flying cat, soft golden fur,
fantasy art drawn by Pixar concept artist,
Toy Story main character, clear and bright eyes, sharp nose'''

imgDic=k.text_to_image(text,1)

# %%
imgUrl=imgDic['images'][0]['image']
imgUrl

import requests
imgData=requests.get(imgUrl, stream=True).raw

from PIL import Image
img=Image.open(imgData)
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>

# %%
imgUrl=imgDic['images'][0]['image']
imgUrl

import requests
imgData=requests.get(imgUrl, stream=True).raw

from PIL import Image
img=Image.open(imgData)
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>

# %%
imgUrl=imgDic['images'][0]['image']
imgUrl

import requests
imgData=requests.get(imgUrl, stream=True).raw

from PIL import Image
img=Image.open(imgData)
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
