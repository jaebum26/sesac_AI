# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15305 (delta 0), reused 1 (delta 0), pack-reused 15300
# Receiving objects: 100% (15305/15305), 14.13 MiB | 24.15 MiB/s, done.
# Resolving deltas: 100% (10497/10497), done.

# %%
# %cd /content/yolov5
# %pwd
# Out:
# /content/yolov5
# '/content/yolov5'

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.
# ...

# %%
#!python detect.py  --source /content/BTS_MV.mp4

# %%
# 참고: 실행하지 않아도 됨
txt='''person, bicycle, car, motorbike, aeroplane, bus, train, truck, boat, traffic light, fire hydrant, stop sign, parking meter,
bench, bird, cat, dog, horse, sheep, cow, elephant, bear, zebra, giraffe, backpack, umbrella, handbag, tie, suitcase, 
fribee, skis, snowboard, sports ball, kite, baseball bat, baseball glove, skateboard, surfboard, tennis racket, bottle,
wine glass, cup, fork, knife, spoon, bowl, banana, apple, sandwich, orange, broccoli, carrot, hot dog, pizza, donut,
cake, chair, sofa, pottedplant, bed, diningtable, toilet, tvmonitor, laptop, mouse, remote, keyboard, cell phone,
microwave, oven, toaster, sink, refrigerator, book, clock, vase, scissors, teddy bear, hair drier, toothbrush'''

bunList=[47,49,47,47,47,49,49,47,49,50,49]

result=[]
for x in bunList:
  result.append(txt.split(',')[x])

import numpy as np
np.unique(result, return_counts=True)
# Out:
# (array([' apple', ' broccoli', ' orange'], dtype='<U9'), array([5, 1, 5]))

# %%
## 모델실행방법1) 옵션없이
## --source 가 없으면 기본으로 설정된 /data/images 에 있는 bus.jpg와 zidan.jpg를 
## 객체인식 소스로 작업함
## 모든 옵션이 없음으로 run에서 설정된 기본값들이 모두 실행됨
# !python detect.py  --save-txt
# Out:
# detect: weights=yolov5s.pt, source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 136MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 18.2ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 14.7ms
# Speed: 0.5ms pre-process, 16.4ms inference, 19.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# ...

# %%
## 모델실행방법2)  --source 자료의 레이블값을 저장
## 레이블값에는  클래스이름, 박스좌표(2번자료 학습)
# !python detect.py --source /content/test/*.jpg --save-txt
# Out:
# detect: weights=yolov5s.pt, source=/content/test/a.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/test/a.jpg: 448x640 24 bowls, 2 apples, 1 orange, 1 dining table, 12.1ms
# Speed: 0.5ms pre-process, 12.1ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7
# 1 labels saved to runs/detect/exp7/labels

# %%
## 모델실행방법2)  --source 자료의 발견된 개체를 별도로 저장
# !python detect.py --source /content/test/*.jpg --save-crop --save-txt
# Out:
# detect: weights=yolov5s.pt, source=/content/test/a.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/test/a.jpg: 448x640 24 bowls, 2 apples, 1 orange, 1 dining table, 12.5ms
# Speed: 0.4ms pre-process, 12.5ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp9
# 1 labels saved to runs/detect/exp9/labels

# %%
import pandas as pd
file=("runs/detect/exp7/labels/a.txt")
data = pd.read_csv(file,  delimiter=' ',
                   names =["class_name", "b", "c", "d",'f'])
data['class_name'].value_counts()
# Out:
# 45    24
# 47     2
# 60     1
# 49     1
# Name: class_name, dtype: int64

# %%
## 모델실행방법2)  내비디오
# !python detect.py --source /content/BTS_MV.mp4 --save-txt
# Out:
# detect: weights=yolov5s.pt, source=/content/BTS_MV.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:01<00:00, 10.2MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/280) /content/BTS_MV.mp4: 384x640 (no detections), 17.9ms
# video 1/1 (2/280) /content/BTS_MV.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (3/280) /content/BTS_MV.mp4: 384x640 (no detections), 8.8ms
# video 1/1 (4/280) /content/BTS_MV.mp4: 384x640 (no detections), 8.8ms
# ...

# %%
## w값을 사용자가 지정, 
# 이미지사이즈도 사용자가 지정
# conf는 확률값의 최저값도 사용자가 지정

# !python detect.py --weights yolov5s.pt --img 640 --conf=0.25 --source data/images

# %%
# !python detect.py --source /content/BTS_MV.mp4 --save-txt --save-crop --vid-stride=24
# Out:
# detect: weights=yolov5s.pt, source=/content/BTS_MV.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=24
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/280) /content/BTS_MV.mp4: 384x640 (no detections), 12.6ms
# video 1/1 (2/280) /content/BTS_MV.mp4: 384x640 (no detections), 13.2ms
# video 1/1 (3/280) /content/BTS_MV.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (4/280) /content/BTS_MV.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (5/280) /content/BTS_MV.mp4: 384x640 1 person, 9.2ms
# ...

# %%
# !zip -r /content/BTS_YOLO.zip /content/yolov5/runs/detect/exp3
# Out:
#   adding: content/yolov5/runs/detect/exp3/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/BTS_MV.mp4 (deflated 10%)
#   adding: content/yolov5/runs/detect/exp3/crops/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/crops/tennis racket/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/crops/tennis racket/BTS_MV.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/crops/tennis racket/BTS_MV2.jpg (deflated 5%)
#   adding: content/yolov5/runs/detect/exp3/crops/cell phone/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/crops/cell phone/BTS_MV.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/crops/cell phone/BTS_MV3.jpg (deflated 3%)
#   adding: content/yolov5/runs/detect/exp3/crops/cell phone/BTS_MV2.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp3/crops/bus/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp3/crops/bus/BTS_MV5.jpg (deflated 2%)
# ...
